# %% [markdown]
# # Notebook 04: Project Improvements & Advanced Extensions
#
# **Project 3.1: Heart Disease Diagnosis Using Machine Learning**
# AI VIET NAM – AI Course 2026 (Extensions & Rubric Honors)
#
# ---
# ### Improvement Areas Covered:
# 1. **Diverse Model Architectures:**
#    - Regularized Logistic Regression (Interpretable linear baseline).
#    - Support Vector Machines (Linear vs. RBF non-linear kernel).
#    - Multi-Layer Perceptron (Neural Network baseline on small tabular data).
#    - Distance-Weighted KNN.
# 2. **Advanced Data Preprocessing & Features:**
#    - `RobustScaler` (Outlier-resistant scaling on `chol` and `trestbps`).
#    - `VarianceThreshold` (Quasi-constant feature elimination).
#    - `PolynomialFeatures` (2nd-order interaction terms).
# 3. **Bayesian Hyperparameter Optimization:**
#    - Multi-parameter joint tuning using **Optuna** (TPE sampler).
# 4. **Model Explainability & Clinical Interpretability:**
#    - **SHAP (SHapley Additive exPlanations)** Summary & Waterfall plots.

# %%
import os
import sys
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

sys.path.append(str(Path.cwd().parent))
from src.config import SEED
from src.models.advanced_models import (
    LogisticRegressionModel,
    SupportVectorMachineModel,
    MultiLayerPerceptronModel,
    WeightedKNNModel
)
from src.tuning.hyperopt import optimize_random_forest_optuna, optimize_xgboost_optuna

print("[✓] Advanced improvements environment loaded.")

# %% [markdown]
# ## 1. Additional Model Benchmarks (SVM, Logistic Regression, MLP)
#
# **TODO:**
# - Train `SupportVectorMachineModel(kernel='rbf', C=1.0)` and `SupportVectorMachineModel(kernel='linear')`.
# - Train `LogisticRegressionModel(penalty='l2', C=1.0)`.
# - Train `MultiLayerPerceptronModel(hidden_layer_sizes=(32, 16), alpha=0.01)`.
# - Compare against Random Forest and XGBoost.

# %%
# TODO: Train and evaluate SVM, Logistic Regression, and MLP

# %% [markdown]
# ## 2. RobustScaler & Polynomial Feature Transformation
#
# **TODO:**
# - Build a pipeline with `RobustScaler` to mitigate extreme cholesterol outliers.
# - Test `PolynomialFeatures(degree=2, interaction_only=True)`.
# - Evaluate whether non-linear features boost Linear / SVM models.

# %%
# TODO: Test RobustScaler and PolynomialFeatures pipeline

# %% [markdown]
# ## 3. Bayesian Hyperparameter Optimization with Optuna
#
# **TODO:**
# - Run 50 trials of Optuna study to find joint optimal parameters for Random Forest / XGBoost.
# - Evaluate performance on the held-out test split.

# %%
# TODO: Execute Optuna study and visualize optimization history
# Hint: optimize_xgboost_optuna(X_train, y_train, n_trials=50)

# %% [markdown]
# ## 4. Explainable AI with SHAP (SHapley Additive exPlanations)
#
# **TODO:**
# - Use `shap.TreeExplainer` on fitted Random Forest or XGBoost model.
# - Generate `shap.summary_plot` to see directional feature impact on disease prediction.
# - Generate `shap.plots.waterfall` for individual patient diagnosis explanations.

# %%
# TODO: Compute and plot SHAP explanations
# import shap
# explainer = shap.TreeExplainer(rf_model.model)
# shap_values = explainer(X_test)
# shap.summary_plot(shap_values, X_test)
