# %% [markdown]
# # Notebook 03: Advanced Ensemble Models & Benchmark Comparison
#
# **Project 3.1: Heart Disease Diagnosis Using Machine Learning**
# AI VIET NAM – AI Course 2026 (Part 2 Experiments)
#
# ---
# ### Objectives:
# 1. Train & evaluate **Random Forest** (Bagging) across 4 dataset configurations.
# 2. Train & evaluate **AdaBoost** (Sequential sample-weight boosting).
# 3. Train & evaluate **Gradient Boosting** (Residual gradient descent).
# 4. Train & evaluate **XGBoost** (Regularized histogram tree boosting).
# 5. Construct the comprehensive 9-model x 4-dataset **Benchmark Comparison Table**.

# %%
import os
import sys
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

sys.path.append(str(Path.cwd().parent))
from src.config import SEED
from src.models.ensemble_models import (
    RandomForestModel,
    AdaBoostModel,
    GradientBoostingModel,
    XGBoostModel
)
from src.evaluation.metrics import print_classification_summary
from src.evaluation.visualization import plot_comparison_bar_chart

print("[✓] Ensemble advancement environment loaded.")

# %% [markdown]
# ## 1. Load All 4 Dataset Configurations
#
# Load train/val/test splits for:
# 1. `Original` (`raw`)
# 2. `FE`
# 3. `Original + DT` (Top-10 DT features)
# 4. `FE + DT` (Top-10 DT features on FE)

# %%
# TODO: Load all 4 dataset variations
# splits_dir = Path("../data/splits")

# %% [markdown]
# ## 2. Random Forest Experiments
#
# **TODO:**
# - Optimize `n_estimators \in [50, 500]` via 3-Fold Stratified CV.
# - Train and evaluate on all 4 dataset variants.
# - Plot 4-dataset grouped bar chart.

# %%
# TODO: Run Random Forest experiments across 4 datasets

# %% [markdown]
# ## 3. AdaBoost Experiments
#
# **TODO:**
# - Optimize `n_estimators` for Decision Stump AdaBoost.
# - Train and evaluate on all 4 dataset variants.

# %%
# TODO: Run AdaBoost experiments across 4 datasets

# %% [markdown]
# ## 4. Gradient Boosting Experiments
#
# **TODO:**
# - Optimize `n_estimators` for Gradient Boosting.
# - Train and evaluate on all 4 dataset variants.

# %%
# TODO: Run Gradient Boosting experiments across 4 datasets

# %% [markdown]
# ## 5. XGBoost Experiments
#
# **TODO:**
# - Optimize `n_estimators` for XGBoost with `tree_method='hist'`.
# - Train and evaluate on all 4 dataset variants.

# %%
# TODO: Run XGBoost experiments across 4 datasets

# %% [markdown]
# ## 6. Master Benchmark Summary Table
#
# **TODO:**
# - Consolidate Validation and Test accuracies for all 9 models across the 4 dataset variants into a formatted pandas DataFrame.

# %%
# TODO: Create and display master benchmark summary table
